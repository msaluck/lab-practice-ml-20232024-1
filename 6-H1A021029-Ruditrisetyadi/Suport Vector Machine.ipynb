# %% [markdown]
# **LOAD DATASETS**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pds
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

sns.set()

#load datasets
iris=load_iris()
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %% [markdown]
# **ANALISIS DATA**

# %%
pds.DataFrame(iris["data"], columns=iris["feature_names"])

# %% [markdown]
# **FITUR DAN LABEL IRIS**

# %%
x = iris.data
y = iris.target

# %% [markdown]
# **TRAIN TEST SPLIT**

# %%
iris_data=iris.data
iris_data.shape
# Out:
# (150, 4)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state = 0)

# %%
x_train.shape
# Out:
# (114, 4)

# %%
x_test.shape
# Out:
# (36, 4)

# %% [markdown]
# **MENSTANDARKAN DATA**

# %%
sc = StandardScaler()
x_train_std = sc.fit_transform(x_train)
x_test_std = sc.fit_transform(x_test)

# %% [markdown]
# **SUPORT VECTOR MACHINE**

# %%
#svmachine = SVC(kernel = 'linear', C=100.0, random_state=0)
#svmachine = SVC(kernel = 'rbf', random_state=0, gamma=100.0, C=10.0)
#svmachine = SVC(kernel = 'poly', random_state=0, gamma=100.0, C=10.0)
svmachine = SVC(kernel = 'sigmoid', random_state=0, gamma=100.0, C=10.0)

# %% [markdown]
# **TRAIN MODEL**

# %%
svmachine.fit(x_train_std, y_train)
# Out:
# SVC(C=10.0, gamma=100.0, kernel='sigmoid', random_state=0)

# %% [markdown]
# **MEMBUAT PREDIKSI MENGGUNAKAN MODEL**

# %%
y_pred = svmachine.predict(x_test_std)
print('prediksi yang salah dari total')
print((y_test != y_pred).sum(),'/',((y_test == y_pred).sum()+(y_test != y_pred).sum()))
print('persentase akurasi: ',100*accuracy_score(y_test, y_pred))
# Out:
# prediksi yang salah dari total
# 13 / 38
# persentase akurasi:  65.78947368421053
